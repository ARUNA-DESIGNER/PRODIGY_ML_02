# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from IPython.display import Image
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# %matplotlib inline

# %%
K_df = pd.read_csv('/content/Mall_Customers .csv')
K_df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
K_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
K_df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
K_df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
mask = K_df['Spending Score (1-100)'] >50
df_score = K_df[mask]
df_score.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 1           2    Male   21                  15                      81
# 3           4  Female   23                  16                      77
# 5           6  Female   22                  17                      76
# 7           8  Female   23                  18                      94
# 9          10  Female   30                  19                      72

# %%
df_score.describe()
# Out:
#        CustomerID        Age  Annual Income (k$)  Spending Score (1-100)
# count   97.000000  97.000000           97.000000               97.000000
# mean   100.298969  34.597938           60.412371               71.670103
# std     59.122783  13.024544           26.756133               14.710910
# min      2.000000  18.000000           15.000000               51.000000
# 25%     51.000000  26.000000           42.000000               57.000000
# 50%     96.000000  31.000000           60.000000               73.000000
# 75%    152.000000  38.000000           78.000000               85.000000
# max    200.000000  70.000000          137.000000               99.000000

# %%
plt.figure(figsize = (15,6))
n=0
for x in ['Age','Annual Income (k$)','Spending Score (1-100)']:
    n += 1
    plt.subplot(2,3,n)
    plt.subplots_adjust(hspace=0.3,wspace = 0.3)
    sns.histplot(K_df[x],bins = 30)
    plt.title('DistPlot of {}'.format(x))
plt.show();

# %%
df_score['Age'].hist()
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Spending Score(51 ~ 100): Age Distribution');

# %%
fig=px.scatter(df_score,x='Annual Income (k$)',y='Spending Score (1-100)',color='Gender')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="777d4527-ca61-451e-8054-69c9d90a9434" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("777d4527-ca61-451e-8054-69c9d90a9434")) {                    Plotly.newPlot(                        "777d4527-ca61-451e-8054-69c9d90a9434",                        [{"hovertemplate":"Gender=Male\u003cbr\u003eAnnual Income (k$)=%{x}\u003cbr\u003eSpending Score (1-100)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Male","orientation":"v","showlegend":true,"x":[15,20,21,24,25,28,28,33,38,42,43,46,46,48,48,48,49,54,54,54,60,62,62,62,63,67,69,71,71,71,73,75,77,78,78,87,87,87,88,93,99,101,126,137],"xaxis":"x","y":[81,79,66,73,73,82,61,92,92,60,60,56,55,51,59,59,55,54,51,55,52,59,55,56,52,56,91,95,75,75,73,93,97,90,88,63,75,92,69,90,97,68,74,83],"yaxis":"y","type":"scatter"},{"hovertemplate":"Gender=Female\u003cbr\u003eAnnual Income (k$)=%{x}\u003cbr\u003eSpending Score (1-100)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Female","orientation":"v","showlegend":true,"x":[16,17,18,19,19,20,23,29,30,33,34,37,39,39,40,42,43,46,47,47,50,54,54,54,57,57,58,59,63,65,67,69,70,72,73,74,76,77,78,78,78,78,79,81,85,86,88,97,98,103,103,113,120],"xaxis":"x","y":[77,76,94,72,99,77,98,87,73,81,73,75,61,65,55,52,54,51,52,59,56,53,52,57,58,55,60,55,54,59,57,58,77,71,88,72,87,74,76,89,78,73,83,93,75,95,86,86,88,85,69,91,79],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0 ...

# %%
fig=px.histogram(df_score,x='Annual Income (k$)',y='Spending Score (1-100)',color='Gender')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="64bef7c0-19eb-4ab4-a8c5-4b2fd6e1f7cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64bef7c0-19eb-4ab4-a8c5-4b2fd6e1f7cc")) {                    Plotly.newPlot(                        "64bef7c0-19eb-4ab4-a8c5-4b2fd6e1f7cc",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Gender=Male\u003cbr\u003eAnnual Income (k$)=%{x}\u003cbr\u003esum of Spending Score (1-100)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"x":[15,20,21,24,25,28,28,33,38,42,43,46,46,48,48,48,49,54,54,54,60,62,62,62,63,67,69,71,71,71,73,75,77,78,78,87,87,87,88,93,99,101,126,137],"xaxis":"x","y":[81,79,66,73,73,82,61,92,92,60,60,56,55,51,59,59,55,54,51,55,52,59,55,56,52,56,91,95,75,75,73,93,97,90,88,63,75,92,69,90,97,68,74,83],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Gender=Female\u003cbr\u003eAnnual Income (k$)=%{x}\u003cbr\u003esum of Spending Score (1-100)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"x":[16,17,18,19,19,20,23,29,30,33,34,37,39,39,40,42,43,46,47,47,50,54,54,54,57,57,58,59,63,65,67,69,70,72,73,74,76,77,78,78,78,78,79,81,85,86,88,97,98,103,103,113,120],"xaxis":"x","y":[77,76,94,72,99,77,98,87,73,81,73,75,61,65,55,52,54,51,52,59,56,53,52,57,58,55,60,55,54,59,57,58,77,71,88,72,87,74,76,89,78,73,83,93,75,95,86,86,88,85,69,91,79],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778 ...

# %%
plt.figure(figsize = (15,4))
sns.countplot(x='Gender',data = df_score)
plt.title('Spending Score (51-100): Gender Distribution')
plt.show();

# %%
plt.figure(figsize = (15,4))
sns.countplot(y='Gender',data = K_df)
plt.title('Spending Score (0-100): Gender Distribution')
plt.show();

# %%
import warnings
warnings.filterwarnings("ignore",category =UserWarning)
sns.pairplot(K_df[['Age','Annual Income (k$)','Spending Score (1-100)']],kind='reg')
plt.tight_layout()
plt.show();

# %%
X = K_df.iloc[:,[3,4]]
print(f"X Shape {X.shape}")
X.head()
# Out:
# X Shape (200, 2)
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
n_clusters = range(2,13)
inertia_errors = []
silhouette_scores = []
for k in n_clusters:
    model = KMeans(n_clusters = k,random_state=42,n_init=10)
    model.fit(X)
    inertia_errors.append(model.inertia_)
    silhouette_scores.append(silhouette_score(X,model.labels_))
print("Inertia:",inertia_errors[:3])
print()
print("Silhouette Scores:",silhouette_scores[:3])
# Out:
# Inertia: [181363.59595959607, 106348.37306211119, 73679.78903948837]
#
# Silhouette Scores: [0.2968969162503008, 0.46761358158775435, 0.4931963109249047]

# %%
x_values = list(range(2, 13))
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
plt.plot(x_values, inertia_errors, marker='o', linestyle='-', color='b')
plt.title('K-Means Model: Inertia vs Number of Clusters')
plt.xlabel('Number Of Clusters')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()

# %%
final_model = KMeans(n_clusters=5,random_state=42,n_init=10)
final_model.fit(X)
# Out:
# KMeans(n_clusters=5, n_init=10, random_state=42)

# %%
optimal_k = 5
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
K_df['Cluster'] = kmeans.fit_predict(X_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
from sklearn.cluster import KMeans
plt.figure(figsize=(10, 6))
sns.scatterplot(data=K_df, x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', palette='viridis')
plt.title('Clusters of Customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
xgb = X.groupby(final_model.labels_).mean()
xgb
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0           55.296296               49.518519
# 1           86.538462               82.128205
# 2           25.727273               79.363636
# 3           88.200000               17.114286
# 4           26.304348               20.913043

# %%
labels = final_model.labels_
centroids = final_model.cluster_centers_
print(labels[:5])
print(centroids[:5])
# Out:
# [4 2 4 2 4]
# [[55.2962963  49.51851852]
#  [86.53846154 82.12820513]
#  [25.72727273 79.36363636]
#  [88.2        17.11428571]
#  [26.30434783 20.91304348]]

# %%
plt.figure(figsize=(8, 6))
x = [0,1,2,3,4]
x_labels = labels
income_values = xgb['Annual Income (k$)']
spending_values = xgb['Spending Score (1-100)']
bar_width = 0.35
index = range(len(x))
plt.bar(index, income_values, bar_width, label='Annual Income')
plt.bar([i + bar_width for i in index], spending_values, bar_width, label='Spending Score')
plt.xlabel('Clusters')
plt.ylabel('Value')
plt.title('Annual Income and Spending Score by Cluster')
plt.xticks([i + bar_width / 2 for i in index], x)
plt.legend()
plt.show()

# %%
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)
cluster_centers_df = pd.DataFrame(cluster_centers, columns=features)
cluster_centers_df['Cluster'] = range(optimal_k)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(cluster_centers_df.set_index('Cluster'), annot=True, cmap='coolwarm')
plt.title('Cluster Centers')
plt.show()

# %%
sns.pairplot(K_df, hue='Cluster', palette='viridis', vars=features)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-6e73face6995> in <cell line: 1>()
# ----> 1 sns.pairplot(K_df, hue='Cluster', palette='viridis', vars=features)
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117     # Set up the PairGrid
#    2118     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                     hue_order=hue_order, palette=palette, corner=corner,
#    2121                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in __init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1325             # to the axes-level functions, while always handling legend creation.
#    1326             # See GH2307
# -> 1327             hue_names = hue_order = categorical_order(data[hue], hue_order)
#    1328             if dropna:
#    1329                 # Filter NA from the list of unique hue names
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Cluster'

# %%
cluster_summary = K_df.groupby('Cluster')[features].mean().reset_index()
print(cluster_summary)

# Save the clustered data
K_df.to_csv('clustered_customers.csv', index=False)
# Out:
#    Cluster        Age  Annual Income (k$)  Spending Score (1-100)
# 0        0  46.250000           26.750000               18.350000
# 1        1  25.185185           41.092593               62.240741
# 2        2  32.875000           86.100000               81.525000
# 3        3  39.871795           86.102564               19.358974
# 4        4  55.638298           54.382979               48.851064
